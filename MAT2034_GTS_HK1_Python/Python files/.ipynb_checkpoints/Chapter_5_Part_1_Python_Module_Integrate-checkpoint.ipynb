# %% [markdown]
# # 5.1. Differentiation - Derivatives

# %%
import scipy as sp
from scipy.misc import derivative
#help(derivative)

f = lambda x: x**3 + x**2

derivative(f, 1.0, dx=1e-6)
# Out:
# 4.999999999921734

# %%
from scipy.optimize._numdiff import approx_derivative, approx_fprime, approx_fhess_p

help(approx_derivative)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7996\4286061131.py in <module>
# ----> 1 from scipy.optimize._numdiff import approx_derivative, approx_fprime, approx_fhess_p
#       2
#       3 help(approx_derivative)
#
# ImportError: cannot import name 'approx_fprime' from 'scipy.optimize._numdiff' (C:\Users\DELL\anaconda3\lib\site-packages\scipy\optimize\_numdiff.py)

# %% [markdown]
# # 5.2. Integration

# %%
import numpy as np
import scipy as sp

help(sp.integrate)
# Out:
# Help on package scipy.integrate in scipy:
#
# NAME
#     scipy.integrate
#
# DESCRIPTION
# ...
#     Integration and ODEs (:mod:`scipy.integrate`)
# ...
#
#     .. currentmodule:: scipy.integrate
#
#     Integrating functions, given function object
# ...
#
#     .. autosummary::
#        :toctree: generated/
#
#        quad          -- General purpose integration
#        quad_vec      -- General purpose integration of vector-valued functions
#        dblquad       -- General purpose double integration
#        tplquad       -- General purpose triple integration
#        nquad         -- General purpose N-D integration
#        fixed_quad    -- Integrate func(x) using Gaussian quadrature of order n
#        quadrature    -- Integrate with given tolerance using Gaussian quadrature
#        romberg       -- Integrate func using Romberg integration
#        newton_cotes  -- Weights and error coefficient for Newton-Cotes integration
#        IntegrationWarning -- Warning on issues during integration
# ...

# %%
from scipy.integrate import quad

from scipy import integrate

x = np.arange(0, 10)
y = np.arange(0, 10)
integrate.simpson(y, x)

y = np.power(x, 3)
integrate.simpson(y, x)
# Out:
# 1642.5

# %%
from scipy.integrate import newton_cotes, fixed_quad, trapz, romberg

# %%
from scipy import integrate
f = lambda x: x**8
integrate.fixed_quad(f, 0.0, 1.0, n=4)
# Out:
# (0.1110884353741496, None)

# %%
from scipy.integrate import newton_cotes
def f(x):
    return np.sin(x)
a = 0
b = np.pi
exact = 2
for N in [2, 4, 6, 8, 10]:
    x = np.linspace(a, b, N + 1)
    an, B = newton_cotes(N, 1)
    dx = (b - a) / N
    quad = dx * np.sum(an * f(x))
    error = abs(quad - exact)
    print('{:2d}  {:10.9f}  {:.5e}'.format(N, quad, error))
# Out:
#  2  2.094395102  9.43951e-02
#  4  1.998570732  1.42927e-03
#  6  2.000017814  1.78136e-05
#  8  1.999999835  1.64725e-07
# 10  2.000000001  1.14677e-09

# %%
from scipy import integrate
from scipy.special import erf
gaussian = lambda x: 1/np.sqrt(np.pi) * np.exp(-x**2)
result = integrate.romberg(gaussian, 0, 1, show=True)
# Out:
# Romberg integration of <function vectorize1.<locals>.vfunc at 0x000002A187319700> from [0, 1]
#
#  Steps  StepSize   Results
#      1  1.000000  0.385872
#      2  0.500000  0.412631  0.421551
#      4  0.250000  0.419184  0.421368  0.421356
#      8  0.125000  0.420810  0.421352  0.421350  0.421350
#     16  0.062500  0.421215  0.421350  0.421350  0.421350  0.421350
#     32  0.031250  0.421317  0.421350  0.421350  0.421350  0.421350  0.421350
#
# The final result is 0.421350396474754 after 33 function evaluations.

# %%
np.trapz([1,2,3], x=[4,6,8])
# Out:
# 8.0

# %%
from scipy import integrate
import matplotlib.pyplot as plt
x = np.linspace(-2, 2, num=20)
y = x
y_int = integrate.cumulative_trapezoid(y, x, initial=0)
plt.plot(x, y_int, 'ro', x, y[0] + 0.5 * x**2, 'b-')
plt.show()

# %%
from scipy import integrate
x = np.arange(0, 10)
y = np.arange(0, 10)
integrate.simpson(y, x)
# Out:
# 40.5

# %%
from scipy import integrate
x = np.arange(10, 14.25, 0.25)
y = np.arange(3, 12)
integrate.romb(y)

y = np.sin(np.power(x, 2.5))
integrate.romb(y)
# Out:
# -0.7425613366722288
